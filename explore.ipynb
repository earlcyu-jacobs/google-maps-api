# %% [markdown]
# # Google Maps API and Python Best Practices

# %% [markdown]
# ## Import libraries

# %%
import os
import math
import folium
import requests
import googlemaps
import pandas as pd
from dotenv import load_dotenv

# %% [markdown]
# ## Load the API key
#
# > Always use ENVIRONMENT VARIABLES for storing credentials (e.g., API keys, usernames, passwords)

# %%
load_dotenv()
api_key = os.getenv('API_KEY')

# %% [markdown]
# ## Create a Google Maps instance

# %%
gmaps = googlemaps.Client(key=api_key)

# %% [markdown]
# ## Scrape data from DepEd
# https://ebeis.deped.gov.ph/beis/reports_info/masterlist

# %% [markdown]
# **DepEd Masterlist of Schools Landing Page**

# %% [markdown]
# ![deped_schools_landing_page](assets/deped_schools_landing_page.png)

# %% [markdown]
# **DepEd Masterlist of Schools Inspect Page**

# %% [markdown]
# ![deped_schools_inspect](assets/deped_schools_inspect.png)

# %% [markdown]
# ### Convert cURL to a Python request
# https://curlconverter.com/

# %%
cookies = {
    'sf_beis': 'maqosutmsq5u5h151p0lsljll4',
    'switchmenu-frontend': '',
}

headers = {
    'authority': 'ebeis.deped.gov.ph',
    'accept': 'text/javascript, text/html, application/xml, text/xml, */*',
    'accept-language': 'en-US,en;q=0.9',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    # 'cookie': 'sf_beis=maqosutmsq5u5h151p0lsljll4; switchmenu-frontend=',
    'origin': 'https://ebeis.deped.gov.ph',
    'referer': 'https://ebeis.deped.gov.ph/beis/reports_info/masterlist',
    'sec-ch-ua': '"Google Chrome";v="113", "Chromium";v="113", "Not-A.Brand";v="24"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36',
    'x-prototype-version': '1.6.0.3',
    'x-requested-with': 'XMLHttpRequest',
}

# This is where you would change the parameters in case you want to get more data
data = {
    'page': '1',
    'school[id]': '',
    'school[school_name]': '',
    'school[co_gen_class]': '',
    'school[general_classification_id]': '',
    'school[curricular_class_id]': '',
    'school[region_id]': '13', # NCR
    'school[division_id]': '1008', # Manila
    'school[user_id]': '',
    'school[school_head]': '',
    'ajax_submit': 'Submit',
    '_': '',
}

response = requests.post(
    'https://ebeis.deped.gov.ph/beis/reports_info/viewMasterList',
    cookies=cookies,
    headers=headers,
    data=data,
)

# %% [markdown]
# ### Check if the request was successful
#
# 200 - success <br/>
# 403 - error

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ### View the data

# %%
schools = pd.read_html(response.text)[0]

# %%
row, col = schools.shape
print(f'{row} rows, {col} columns')
# Out:
# 30 rows, 5 columns

# %%
schools.head()
# Out:
#    School ID                                        School Name  \
# 0     136418                    A. C. Herrera Elementary School
# 1     136453                        A. Mabini Elementary School
# 2     136436                  A. V. Hernandez Elementary School
# 3     409082              A. Veloso Pre-school Foundation, Inc.
# 4     401141  ABE International College of Business & Econom...
#
#                                      Head / Position  \
# 0        FABONAN, NICHOL WAYNE FERRIOL - Principal I
# 1             SAMPANG, RODEL CUNANAN - Principal III
# 2             SORIANO, EMMANUEL REYES - Principal IV
# 3                 AVPSF, AVPSF AVPSF - Administrator
# 4  ABE COLLEGE-MANILA, ABE COLLEGE-MANILA ABE COL...
#
#                         Address         School Type
# 0                S. Teodoro St.  Kinder & Grade 1-6
# 1           Severino-Soler St.,  Kinder & Grade 1-6
# 2  Sto. Niño St., Bo. Magsaysay  Kinder & Grade 1-6
# 3       1706 G. Perfecto Street              Kinder
# 4           2578 Legarda Street         Grade 11-12

# %% [markdown]
# ### Remove duplicates

# %%
# There are some schools with the same school name and address but different school IDs
schools.drop_duplicates(subset=['School Name', 'Address'], ignore_index=True, inplace=True)

# %%
schools.head()
# Out:
#    School ID                                        School Name  \
# 0     136418                    A. C. Herrera Elementary School
# 1     136453                        A. Mabini Elementary School
# 2     136436                  A. V. Hernandez Elementary School
# 3     409082              A. Veloso Pre-school Foundation, Inc.
# 4     401141  ABE International College of Business & Econom...
#
#                                      Head / Position  \
# 0        FABONAN, NICHOL WAYNE FERRIOL - Principal I
# 1             SAMPANG, RODEL CUNANAN - Principal III
# 2             SORIANO, EMMANUEL REYES - Principal IV
# 3                 AVPSF, AVPSF AVPSF - Administrator
# 4  ABE COLLEGE-MANILA, ABE COLLEGE-MANILA ABE COL...
#
#                         Address         School Type
# 0                S. Teodoro St.  Kinder & Grade 1-6
# 1           Severino-Soler St.,  Kinder & Grade 1-6
# 2  Sto. Niño St., Bo. Magsaysay  Kinder & Grade 1-6
# 3       1706 G. Perfecto Street              Kinder
# 4           2578 Legarda Street         Grade 11-12

# %% [markdown]
# ## Geocoding

# %% [markdown]
# ### Geocode 1 school

# %% [markdown]
# **A.C. Herrera Elementary School**

# %%
schools[schools['School ID'] == 136418]
# Out:
#    School ID                      School Name  \
# 0     136418  A. C. Herrera Elementary School
#
#                                Head / Position         Address  \
# 0  FABONAN, NICHOL WAYNE FERRIOL - Principal I  S. Teodoro St.
#
#           School Type
# 0  Kinder & Grade 1-6

# %%
ac_herrera = schools.loc[0, 'School Name'] + ' ' + schools.loc[0, 'Address']
ac_herrera
# Out:
# 'A. C. Herrera Elementary School S. Teodoro St.'

# %%
ac_herrera_response = gmaps.geocode(ac_herrera)
ac_herrera_response
# Out:
# [{'address_components': [{'long_name': 'JXMJ+M4W',
#     'short_name': 'JXMJ+M4W',
#     'types': ['plus_code']},
#    {'long_name': 'Tondo',
#     'short_name': 'Tondo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'JXMJ+M4W, Tondo, Manila, Metro Manila, Philippines',
#   'geometry': {'location': {'lat': 14.634225, 'lng': 120.9803436},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 14.6355700802915,
#      'lng': 120.9816684802915},
#     'southwest': {'lat': 14.6328721197085, 'lng': 120.9789705197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJHxQw9yy1lzMR47tmIabjf7Q',
#   'types': ['establishment', 'point_of_interest', 'school']}]

# %%
ac_herrera_location = ac_herrera_response[0]['geometry']['location']
ac_herrera_location
# Out:
# {'lat': 14.634225, 'lng': 120.9803436}

# %% [markdown]
# **A. Mabini Elementary School**

# %%
schools[schools['School ID'] == 136453]
# Out:
#    School ID                  School Name  \
# 1     136453  A. Mabini Elementary School
#
#                           Head / Position              Address  \
# 1  SAMPANG, RODEL CUNANAN - Principal III  Severino-Soler St.,
#
#           School Type
# 1  Kinder & Grade 1-6

# %%
a_mabini = schools.loc[1, 'School Name'] + ' ' + schools.loc[1, 'Address']
a_mabini
# Out:
# 'A. Mabini Elementary School Severino-Soler St.,'

# %%
a_mabini_response = gmaps.geocode(a_mabini)
a_mabini_response
# Out:
# [{'address_components': [{'long_name': '1001',
#     'short_name': '1001',
#     'types': ['street_number']},
#    {'long_name': 'Severino Street',
#     'short_name': 'Severino St',
#     'types': ['route']},
#    {'long_name': 'Quiapo',
#     'short_name': 'Quiapo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']},
#    {'long_name': '1001', 'short_name': '1001', 'types': ['postal_code']}],
#   'formatted_address': '1001 Severino St, Quiapo, Manila, 1001 Metro Manila, Philippines',
#   'geometry': {'location': {'lat': 14.6014479, 'lng': 120.9859112},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 14.6028625802915,
#      'lng': 120.9871028802915},
#     'southwest': {'lat': 14.6001646197085, 'lng': 120.9844049197085}}},
#   'partial_match': True,
#   'place_id': 'ChIJH8H87gLKlzMRmIIsI7Z6t04',
#   'plus_code': {'compound_code': 'JX2P+H9 Manila, Metro Manila, Philippines',
#    'global_code': '7Q62JX2P+H9'},
#   'types': ['establishment', 'point_of_interest', 'primary_school', 'school']}]

# %% [markdown]
# > Notice that there are more address components

# %%
a_mabini_location = a_mabini_response[0]['geometry']['location']
a_mabini_location
# Out:
# {'lat': 14.6014479, 'lng': 120.9859112}

# %% [markdown]
# ### Create a helper function for identifying address components

# %%
a_mabini_address = pd.json_normalize(a_mabini_response[0]['address_components'])
a_mabini_address
# Out:
#          long_name   short_name                                          types
# 0             1001         1001                                [street_number]
# 1  Severino Street  Severino St                                        [route]
# 2           Quiapo       Quiapo  [political, sublocality, sublocality_level_1]
# 3           Manila       Manila                          [locality, political]
# 4     Metro Manila          NCR       [administrative_area_level_1, political]
# 5      Philippines           PH                           [country, political]
# 6             1001         1001                                  [postal_code]

# %%
a_mabini_address[a_mabini_address['types'].apply(lambda x: 'sublocality' in x)]['long_name'].values[0]
# Out:
# 'Quiapo'

# %%
def get_address_components(df: pd.DataFrame):
    try:
        district = df[df['types'].apply(lambda x: 'sublocality' in x)]['long_name'].values[0]
    except:
        district = None
    try:
        city = df[df['types'].apply(lambda x: 'locality' in x)]['long_name'].values[0]
    except:
        city = None
    try:
        region = df[df['types'].apply(lambda x: 'administrative_area_level_1' in x)]['long_name'].values[0]
    except:
        region = None
    try:
        country = df[df['types'].apply(lambda x: 'country' in x)]['long_name'].values[0]
    except:
        country = None
    return (district, city, region, country)

# %%
get_address_components(a_mabini_address)
# Out:
# ('Quiapo', 'Manila', 'Metro Manila', 'Philippines')

# %% [markdown]
# ### Geocode all schools

# %%
for index in range(len(schools)):
    
    # Concatenate School Name and Address to get the most specific address possible
    complete_address = schools.loc[index, 'School Name'] + ' ' + schools.loc[index, 'Address']
    
    # Geocode the complete address
    gmaps_response = gmaps.geocode(complete_address)
    
    # Ensure that there is a response
    if gmaps_response != []:
        location = gmaps_response[0]['geometry']['location']
        #if location != []:
        # Get the required values
        lat = location['lat']
        lng = location['lng']

        # Place the required values into the dataframe
        schools.loc[index, 'Latitude'] = lat
        schools.loc[index, 'Longitude'] = lng
                   
        address = pd.json_normalize(gmaps_response[0]['address_components'])
        #if address != []:
        # Get the required values
        district, city, region, country = get_address_components(address)        

        # Place the required values into the dataframe
        schools.loc[index, 'District'] = district
        schools.loc[index, 'City'] = city
        schools.loc[index, 'Region'] = region
        schools.loc[index, 'Country'] = country

# %%
schools
# Out:
#     School ID                                        School Name  \
# 0      136418                    A. C. Herrera Elementary School
# 1      136453                        A. Mabini Elementary School
# 2      136436                  A. V. Hernandez Elementary School
# 3      409082              A. Veloso Pre-school Foundation, Inc.
# 4      401141  ABE International College of Business & Econom...
# 5      401135  ABE International College of Business and Acco...
# 6      405674  Access Computer and Technical College-Manila C...
# 7      405679                       ACLC College of Manila, Inc.
# 8      406359                                 Adamson University
# 9      408536          Adonai Conservative Baptist Academy. Inc.
# 10     482110  Affordable Private Education Center (APEC Scho...
# 11     482111  Affordable Private Education Center, Inc. (APE...
# 12     482108  Affordable Private Education Center, Inc. (APE...
# 13    1482002                     Aguinaldo International School
# 14     482049                      AIM Christian Learning Center
# 15     410454                 Al-Ilm Arabic English School, Inc.
# 16     401143             AMA Computer College - Sta. Mesa, Inc.
# 17     406506                AMA Computer Learning Center - Paco
# 18     401144     AMA Computer Learning Center of Northbay, Inc.
# 19     408498                    Amazing Kids Preschoolers, Inc.
# 20     136446                 Andres Bonifacio Elementary School
# 21     408538                        Angels of Hope Academy Inc.
# 22     136469                Antonio A. Maceda Integrated School
# 23     305305           Antonio A. Maceda Integrated School (HS)
# 24     305292         Antonio J. Villegas Vocational High School
# 25     136422                     Antonio Luna Elementary School
#
#                                       Head / Position  \
# 0         FABONAN, NICHOL WAYNE FERRIOL - Principal I
# 1              SAMPANG, RODEL CUNANAN - Principal III
# 2              SORIANO, EMMANUEL REYES - Principal IV
# 3                  AVPSF, AVPSF AVPSF - Administrator
# 4   ABE COLLEGE-MANILA, ABE COLLEGE-MANILA ABE COL...
# 5   ABE COLLEGE-TAFT, ABE COLLEGE-TAFT ABE COLLEGE...
# 6                    ROS, ROSEMARIE M - Administrator
# 7   AMA CLC-MORAYTA, AMA CLC-MORAYTA AMA CLC-MORAY...
# 8                    ELMAR MONTARIL ABAYA - Principal
# 9    ANTONIO IBARRA SAMONTE JR - School Administrator
# 10           GONZAGA, ROENE AILE PENERA - School Head
# 11                SELUDO, ROSAREA HERCE - School Head
# 12  APECSCHOOLS-TONDO, APECSCHOOLS-TONDO APEC - Sc...
# 13        SCHOOL, AGUINALDO INTERNATIONAL - Principal
# 14  AIM Christian Learning Center AIM Christian Le...
# 15                                                  -
# 16          ALEJANDRO, EVITA M - School Administrator
# 17       ENRIQUEZ, GIRLIE TAGALICUD - SCHOOL DIRECTOR
# 18  AMA CLC-NORTHBAY, AMA CLC-NORTHBAY AMA CLC-NOR...
# 19                     AKPI AKPI AKPI - Administrator
# 20              DIOMEDES TAGUBA ROSETE - Principal IV
# 21                         AHAI AHAI AHAI - Principal
# 22                  MARILYN S ATIENZA - Principal III
# 23              JULIUS JESTRE JARDIOLIN - Principal I
# 24  BONDOC, ARACELI TAGUINOD - Secondary School Pr...
# 25                 FERNANDO N. MAGALANG - PRINCIPAL I
#
#                                               Address  \
# 0                                      S. Teodoro St.
# 1                                 Severino-Soler St.,
# 2                        Sto. Niño St., Bo. Magsaysay
# 3                             1706 G. Perfecto Street
# 4                                 2578 Legarda Street
# 5   West East Center Bldg. 1336 Taft Ave. cor. Pad...
# 6   2nd Floor, Access Bldg., C. M. Recto cor. Quez...
# 7                2355 Legarda corner Manrique Streets
# 8                       900 San Marcelino St., Ermita
# 9                  2361-A Laura St., Pandacan, Manila
# 10                España Boulevard Corner Sisa Street
# 11              3F DB Building, 1318 G. Tuazon Street
# 12   CVM 2000 Building Gamban corner C. Playa Streets
# 13          1113-1117 San Marcelino St. Ermita Manila
# 14                  507 F Dalupan St. Sampaloc Manila
# 15                  951 Edward Suites, Arlegui Street
# 16  3299 R. Magsaysay Boulevard corner Maganda Str...
# 17  3rd Flr., LLS Bldg, 934-936 Pedro Gil St., cor...
# 18  3/F MTSC Building, Juan Luna corner Capulong S...
# 19                     517 Pacheco St., tondo, Manila
# 20                              Ipil-Tayuman Streets,
# 21  2239 E. Rodriguez cor. Nava St., Balut, Tondo,...
# 22                      Buenos Aires cor. Mangga Ave.
# 23                 Buenos Aires St., Sta. Mesa Manila
# 24                                     Jacinto Street
# 25                                     2701 Lico St.,
#
#                                           School Type   Latitude   Longitude  \
# 0                                  Kinder & Grade 1-6  14.634225  120.980344
# 1                                  Kinder & Grade 1-6  14.601448  120.985911
# 2                                  Kinder & Grade 1-6  14.619134  120.960874
# 3                                              Kinder  14.615034  120.972026
# 4                                         Grade 11-12  14.600425  120.996037
# 5                                         Grade 11-12  14.579664  120.986584
# 6                                         Grade 11-12  14.604614  120.977963
# 7                                         Grade 11-12  14.600770  120.995174
# 8   Kinder, Grade 1-6, Grade 7-10 & Grade 11-12 at...  14.587478  120.985616
# 9                                  Kinder & Grade 1-6  14.589693  121.006223
# 10                           Grade 7-10 & Grade 11-12  14.615250  120.998673
# 11                           Grade 7-10 & Grade 11-12  14.602584  120.994771
# 12                           Grade 7-10 & Grade 11-12  14.629286  121.012818
# 13        Kinder, Grade 1-6, Grade 7-10 & Grade 11-12  14.582326  120.986556
# 14                                 Kinder & Grade 1-6  14.600832  120.991110
# 15                                 Kinder & Grade 1-6  14.596536  120.989298
# 16                                        Grade 11-12  14.601893  121.005231
# 17                                        Grade 11-12  14.576576  120.989781
# 18                                        Grade 11-12  14.620337  120.965089
# 19                                             Kinder  14.613793  120.967388
# 20                                 Kinder & Grade 1-6   7.785836  122.588174
# 21                                 Kinder & Grade 1-6  14.630648  120.966099
# 22                                          Grade 1-6 -34.603684  -58.381559
# 23                                         Grade 7-10  14.603359  121.011986
# 24                                         Grade 7-10        NaN         NaN
# 25                                 Kinder & Grade 1-6  14.626331  120.981851
#
#                District          City               Region      Country
# 0                 Tondo        Manila         Metro Manila  Philippines
# 1                Quiapo        Manila         Metro Manila  Philippines
# 2            107, Tondo        Manila         Metro Manila  Philippines
# 3                 Tondo        Manila         Metro Manila  Philippines
# 4              Sampaloc        Manila         Metro Manila  Philippines
# 5                Ermita        Manila         Metro Manila  Philippines
# 6               Binondo        Manila         Metro Manila  Philippines
# 7                  None        Manila         Metro Manila  Philippines
# 8                Ermita        Manila         Metro Manila  Philippines
# 9   860 Pandacan manila        Manila         Metro Manila  Philippines
# 10             Sampaloc        Manila         Metro Manila  Philippines
# 11             Sampaloc       Maynila    Kalakhang Maynila  Philippines
# 12         Sto. Domingo   Quezon City         Metro Manila  Philippines
# 13               Ermita        Manila         Metro Manila  Philippines
# 14             Sampaloc        Manila         Metro Manila  Philippines
# 15                 None        Manila         Metro Manila  Philippines
# 16             Sampaloc        Manila         Metro Manila  Philippines
# 17               Malate        Manila         Metro Manila  Philippines
# 18                Tondo        Manila         Metro Manila  Philippines
# 19                Tondo        Manila         Metro Manila  Philippines
# 20                 None          Ipil  Zamboanga Peninsula  Philippines
# 21          131 Zone 11        Manila         Metro Manila  Philippines
# 22                 None  Buenos Aires         Buenos Aires    Argentina
# 23             Sampaloc        Manila         Metro Manila  Philippines
# 24                  NaN           NaN                  NaN          NaN
# 25                Tondo        Manila         Metro Manila  Philippines

# %% [markdown]
# ### Plot the coordinates

# %%
# Create a base map
mapa = folium.Map()

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4901e57bc1017a66a03da3c5053d6cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4901e57bc1017a66a03da3c5053d6cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4901e57bc1017a66a03da3c5053d6cd = L.map(
#                 &quot;map_f4901e57bc1017a66a03da3c5053d6cd&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eea47fecc9bf3d39fa7bc36d5a23daab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f4901e57bc1017a66a03da3c5053d6cd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Plot the schools

# %%
for index, elements in schools.iterrows():
    if math.isnan(elements['Latitude']) or math.isnan(elements['Longitude']):
        continue
    else:
        folium.Marker(
            location=(elements['Latitude'], elements['Longitude']),
            popup=elements['School Name'],
            tooltip='click'
        ).add_to(mapa)

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f4901e57bc1017a66a03da3c5053d6cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f4901e57bc1017a66a03da3c5053d6cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f4901e57bc1017a66a03da3c5053d6cd = L.map(
#                 &quot;map_f4901e57bc1017a66a03da3c5053d6cd&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eea47fecc9bf3d39fa7bc36d5a23daab = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f4901e57bc1017a66a03da3c5053d6cd);
#
#
#             var marker_74f61b7abc5cd63d8ff078dce3432589 = L.marker(
#                 [14.634225, 120.9803436],
#                 {}
#             ).addTo(map_f4901e57bc1017a66a03da3c5053d6cd);
#
#
#         var popup_d15be2ce359507bafd8892772d31393e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c16401afc5a093b247cde36043d4c6b1 = $(`&lt;div id=&quot;html_c16401afc5a093b247cde36043d4c6b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A. C. Herrera Elementary School&lt;/div&gt;`)[0];
#                 popup_d15be2ce359507bafd8892772d31393e.setContent(html_c16401afc5a093b247cde36043d4c6b1);
#
#
#
#         marker_74f61b7abc5cd63d8ff078dce3432589.bindPopup(popup_d15be2ce359507bafd8892772d31393e)
#         ;
#
#
#
#
#             marker_74f61b7abc5cd63d8ff078dce3432589.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3d62ab8562a4e6a4d58d8a7b945ef1db = L.marker(
#                 [14.6014479, 120.9859112],
#                 {}
#             ).addTo(map_f4901e57bc1017a66a03da3c5053d6cd);
#
#
#         var popup_2552dd357b000c9c6770547788393bac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd305d7ab6958cb88dedd582b8bbca4b = $(`&lt;div id=&quot;html_dd305d7ab6958cb88dedd582b8bbca4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A. Mabini Elementary School&lt;/div&gt;`)[0];
#                 popup_2552dd357b000c9c6770547788393bac.setContent(html_dd305d7ab6958cb88dedd582b8bbca4b);
#
#
#
#         marker_3d62ab8562a4e6a4d58d8a7b945ef1db.bindPopup(popup_2552dd357b000c9c6770547788393bac)
#         ;
#
#
#
#
#             marker_3d62ab8562a4e6a4d58d8a7b945ef1db.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b517607eb5820cf881073aa8e04de237 = L.marker(
#                 [14.6191337, 120.9608738],
#                 {}
#             ).addTo(map_f4901e57bc1017a66a03da3c5053d6cd);
#
#
#         var popup_a4d829032ee00d7ac9958d325c5e5faa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3adb867af4448391ac8d347444b32e61 = $(`&lt;div id=&quot;html_3adb867af4448391ac8d347444b32e61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A. V. Hernandez Elementary School&lt;/div&gt;`)[0];
#                 popup_a4d829032ee00d7ac9958d325c5e5faa.setContent(html_3adb867af4448391ac8d347444b32e61);
#
#
#
#         marker_b517607eb5820cf881073aa8e04de237.bindPopup(popup_a4d829032ee00d7ac9958d325c5e5faa)
#         ;
#
#
#
#
#             marker_b517607eb5820cf881073aa8e04de237.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8b623a5af397f5cc334827b19b6711ff = L.marker(
#                 [14.615034, 120.9720256],
#                 {}
#             ).addTo(map_f4901e57bc1017a66a03da3c5053d6cd);
#
#
#         var popup_a6edde7bf22e174163a5e86e70ffc4af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_488ab1dd0fe8b76d81e8e500cf4b8b0e = $(`&lt;div id=&quot;html_488ab1dd0fe8b76d81e8e500cf4b8b0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A. Veloso Pre-school Foundation, Inc.&lt;/div&gt;`)[0];
#                 popup_a6edde7bf22e174163a5e86e70ffc4af.setContent(html_488ab1dd0fe8b76d81e8e500cf4b8b0e);
#
#
#
#         marker_8b623a5af397f5cc334827b19b6711ff.bindPopup(popup_a6edde7bf22e174163a5e86e70ffc4af)
#         ;
#
#
#
#
#             marker_8b623a5af397f5cc334827b19b6711ff.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&q

# %% [markdown]
# ## Reverse geocoding

# %%
ac_herrera_location
# Out:
# {'lat': 14.634225, 'lng': 120.9803436}

# %%
gmaps.reverse_geocode(ac_herrera_location)
# Out:
# [{'address_components': [{'long_name': 'JXMJ+M4W',
#     'short_name': 'JXMJ+M4W',
#     'types': ['plus_code']},
#    {'long_name': 'Tondo',
#     'short_name': 'Tondo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'JXMJ+M4W, Tondo, Manila, Metro Manila, Philippines',
#   'geometry': {'location': {'lat': 14.634225, 'lng': 120.9803436},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 14.6355739802915,
#      'lng': 120.9816925802915},
#     'southwest': {'lat': 14.6328760197085, 'lng': 120.9789946197085}}},
#   'place_id': 'ChIJHxQw9yy1lzMR47tmIabjf7Q',
#   'types': ['establishment', 'point_of_interest', 'school']},
#  {'address_components': [{'long_name': '600',
#     'short_name': '600',
#     'types': ['street_number']},
#    {'long_name': 'Santos Teodoro Street',
#     'short_name': 'Santos Teodoro St',
#     'types': ['route']},
#    {'long_name': 'Tondo',
#     'short_name': 'Tondo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Caloocan',
#     'short_name': 'Caloocan',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']},
#    {'long_name': '1400', 'short_name': '1400', 'types': ['postal_code']}],
#   'formatted_address': '600 Santos Teodoro St, Tondo, Caloocan, 1400 Metro Manila, Philippines',
#   'geometry': {'location': {'lat': 14.634164, 'lng': 120.980359},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 14.6355129802915,
#      'lng': 120.9817079802915},
#     'southwest': {'lat': 14.6328150197085, 'lng': 120.9790100197085}}},
#   'place_id': 'ChIJx4XrSty1lzMREiMPsEXBw_U',
#   'plus_code': {'compound_code': 'JXMJ+M4 Caloocan, Metro Manila, Philippines',
#    'global_code': '7Q62JXMJ+M4'},
#   'types': ['street_address']},
#  {'address_components': [{'long_name': '1440',
#     'short_name': '1440',
#     'types': ['street_number']},
#    {'long_name': 'Santos Teodoro Street',
#     'short_name': 'Santos Teodoro St',
#     'types': ['route']},
#    {'long_name': 'Tondo',
#     'short_name': 'Tondo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Valenzuela',
#     'short_name': 'Valenzuela',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': '1440 Santos Teodoro St, Tondo, Valenzuela, Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.6341932, 'lng': 120.9802936},
#     'southwest': {'lat': 14.6341362, 'lng': 120.9802374}},
#    'location': {'lat': 14.6341682, 'lng': 120.9802717},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 14.6355136802915,
#      'lng': 120.9816144802915},
#     'southwest': {'lat': 14.6328157197085, 'lng': 120.9789165197085}}},
#   'place_id': 'ChIJa-OoTNy1lzMRRXd4qLkIhPM',
#   'types': ['premise']},
#  {'address_components': [{'long_name': '675',
#     'short_name': '675',
#     'types': ['street_number']},
#    {'long_name': 'Santos Teodoro Street',
#     'short_name': 'Santos Teodoro St',
#     'types': ['route']},
#    {'long_name': 'Tondo',
#     'short_name': 'Tondo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': '675 Santos Teodoro St, Tondo, Manila, Metro Manila, Philippines',
#   'geometry': {'location': {'lat': 14.6341969, 'lng': 120.9802908},
#    'location_type': 'RANGE_INTERPOLATED',
#    'viewport': {'northeast': {'lat': 14.6355458802915,
#      'lng': 120.9816397802915},
#     'southwest': {'lat': 14.6328479197085, 'lng': 120.9789418197085}}},
#   'place_id': 'Ej82NzUgU2FudG9zIFRlb2Rvcm8gU3QsIFRvbmRvLCBNYW5pbGEsIE1ldHJvIE1hbmlsYSwgUGhpbGlwcGluZXMiGxIZChQKEgmnjtNK3LWXMxGKp1TdFoPNrBCjBQ',
#   'types': ['street_address']},
#  {'address_components': [{'long_name': 'JXMJ+M4',
#     'short_name': 'JXMJ+M4',
#     'types': ['plus_code']},
#    {'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'JXMJ+M4 Manila, Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.63425, 'lng': 120.980375},
#     'southwest': {'lat': 14.634125, 'lng': 120.98025}},
#    'location': {'lat': 14.634225, 'lng': 120.980344},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 14.6355364802915,
#      'lng': 120.9816614802915},
#     'southwest': {'lat': 14.6328385197085, 'lng': 120.9789635197085}}},
#   'place_id': 'GhIJdpyiI7lELUARG7XC9L0-XkA',
#   'plus_code': {'compound_code': 'JXMJ+M4 Manila, Metro Manila, Philippines',
#    'global_code': '7Q62JXMJ+M4'},
#   'types': ['plus_code']},
#  {'address_components': [{'long_name': '600-1145',
#     'short_name': '600-1145',
#     'types': ['street_number']},
#    {'long_name': 'Santos Teodoro Street',
#     'short_name': 'Santos Teodoro St',
#     'types': ['route']},
#    {'long_name': 'Tondo',
#     'short_name': 'Tondo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': '600-1145 Santos Teodoro St, Tondo, Manila, Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.6345414, 'lng': 120.9803733},
#     'southwest': {'lat': 14.6337641, 'lng': 120.9802382}},
#    'location': {'lat': 14.6341518, 'lng': 120.9802987},
#    'location_type': 'GEOMETRIC_CENTER',
#    'viewport': {'northeast': {'lat': 14.6355017302915,
#      'lng': 120.9816547302915},
#     'southwest': {'lat': 14.6328037697085, 'lng': 120.9789567697085}}},
#   'place_id': 'ChIJp47TSty1lzMRiqdU3RaDzaw',
#   'types': ['route']},
#  {'address_components': [{'long_name': 'Brgy. 197',
#     'short_name': 'Brgy. 197',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Tondo',
#     'short_name': 'Tondo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Brgy. 197, Tondo, Manila, Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.6345148, 'lng': 120.981456},
#     'southwest': {'lat': 14.6333756, 'lng': 120.9802357}},
#    'location': {'lat': 14.6338612, 'lng': 120.9806414},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 14.6352941802915,
#      'lng': 120.9821948302915},
#     'southwest': {'lat': 14.6325962197085, 'lng': 120.9794968697085}}},
#   'place_id': 'ChIJs9qlzN21lzMRMb3mwKuXvrw',
#   'types': ['neighborhood', 'political']},
#  {'address_components': [{'long_name': '197',
#     'short_name': '197',
#     'types': ['administrative_area_level_5', 'political']},
#    {'long_name': 'Tondo',
#     'short_name': 'Tondo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': '197, Tondo, Manila, Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.634512, 'lng': 120.981464},
#     'southwest': {'lat': 14.6333599, 'lng': 120.980239}},
#    'location': {'lat': 14.6338612, 'lng': 120.9806414},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 14.6352849302915,
#      'lng': 120.9822004802915},
#     'southwest': {'lat': 14.6325869697085, 'lng': 120.9795025197085}}},
#   'place_id': 'ChIJ12ekzN21lzMRhbrVQaSK8G0',
#   'types': ['administrative_area_level_5', 'political']},
#  {'address_components': [{'long_name': 'Tondo',
#     'short_name': 'Tondo',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Tondo, Manila, Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.6387942, 'lng': 120.9830761},
#     'southwest': {'lat': 14.5947555, 'lng': 120.9415126}},
#    'location': {'lat': 14.6205653, 'lng': 120.9659671},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 14.6387942, 'lng': 120.9830761},
#     'southwest': {'lat': 14.5947555, 'lng': 120.9415126}}},
#   'place_id': 'ChIJrQILto21lzMRbmXoIQYkJM4',
#   'types': ['political', 'sublocality', 'sublocality_level_1']},
#  {'address_components': [{'long_name': 'City Of Manila',
#     'short_name': 'City Of Manila',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'City Of Manila, Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.644325, 'lng': 121.0261619},
#     'southwest': {'lat': 14.5595541, 'lng': 120.941652}},
#    'location': {'lat': 14.6010326, 'lng': 120.9761599},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 14.644325, 'lng': 121.0261619},
#     'southwest': {'lat': 14.5595541, 'lng': 120.941652}}},
#   'place_id': 'ChIJZTW3DwPKlzMR5bMjW7lFcDw',
#   'types': ['administrative_area_level_3', 'political']},
#  {'address_components': [{'long_name': 'Manila',
#     'short_name': 'Manila',
#     'types': ['locality', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Manila, Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.6390175, 'lng': 121.0261686},
#     'southwest': {'lat': 14.5539791, 'lng': 120.932951}},
#    'location': {'lat': 14.5995124, 'lng': 120.9842195},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 14.6390175, 'lng': 121.0261686},
#     'southwest': {'lat': 14.5539791, 'lng': 120.932951}}},
#   'place_id': 'ChIJi8MeVwPKlzMRH8FpEHXV0Wk',
#   'types': ['locality', 'political']},
#  {'address_components': [{'long_name': 'Metro Manila',
#     'short_name': 'Metro Manila',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.7874961, 'lng': 121.1350759},
#     'southwest': {'lat': 14.3480961, 'lng': 120.9062111}},
#    'location': {'lat': 14.6443697, 'lng': 121.03351},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 14.7874961, 'lng': 121.1350759},
#     'southwest': {'lat': 14.3480961, 'lng': 120.9062111}}},
#   'place_id': 'ChIJLzIwE6bJlzMRp1iM6AKFnz4',
#   'types': ['administrative_area_level_2', 'political']},
#  {'address_components': [{'long_name': 'Metro Manila',
#     'short_name': 'NCR',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Metro Manila, Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 14.7874961, 'lng': 121.1350759},
#     'southwest': {'lat': 14.3480961, 'lng': 120.9062111}},
#    'location': {'lat': 14.6090537, 'lng': 121.0222565},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 14.7874961, 'lng': 121.1350759},
#     'southwest': {'lat': 14.3480961, 'lng': 120.9062111}}},
#   'place_id': 'ChIJbTgmYNLIlzMR0HiSrNoj7V8',
#   'types': ['administrative_area_level_1', 'political']},
#  {'address_components': [{'long_name': 'Philippines',
#     'short_name': 'PH',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Philippines',
#   'geometry': {'bounds': {'northeast': {'lat': 21.2412572, 'lng': 127.6444784},
#     'southwest': {'lat': 4.2259, 'lng': 116.1474999}},
#    'location': {'lat': 12.879721, 'lng': 121.774017},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': 21.2412572, 'lng': 127.6444784},
#     'southwest': {'lat': 4.2259, 'lng': 116.1474999}}},
#   'place_id': 'ChIJY96HXyFTQDIRV9opeu-QR3g',
#   'types': ['country', 'political']}]
